# %%
import sys
import pandas as pd
import csv
import numpy as np

# %%
df = pd.read_csv('../datasets/fatal.csv')
names = df.columns
df = df.drop(names[0], axis=1)
df["ageRange"] = 0

# %%
for index, row in df.iterrows():
    age = row[5]
    if age < 20 and age >= 0:
        df.loc[index,"ageRange"] = "00-20"
    elif age >= 20 and age < 30:
        df.loc[index,"ageRange"] = "20-30"
    elif age >= 30 and age < 40:
        df.loc[index,"ageRange"] = "30-40"
    elif age >= 40 and age < 50:
        df.loc[index,"ageRange"] = "40-50"
    elif age >= 50 and age < 60:
        df.loc[index,"ageRange"] = "50-60"
    elif age >= 60 and age < 99:
        df.loc[index,"ageRange"] = "60-99"

# %%
df.to_csv('../datasets/fatalFinal.csv')
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  state_pop  Ethnicity ageRange
# ...

# %%
new = {}
for index, row in df.iterrows():
    year = row[2].split("-")[0]
    s = row[2].split("-")[1]
    if (year+":"+s) in new.keys():
        new.update({year+":"+s:new[year+":"+s]+1})
    else:
        new.update({year+":"+s:1})

# %%
bodycamera= {}
falseCam = []
trueCam = []
for index, row in df.iterrows():
    year = row[2].split("-")[0]
    s = row[2].split("-")[1]
    cam = row[13]
    if cam == True:
        trueCam.append(row)
    else:
        falseCam.append(row)
    if cam in new.keys():
        bodycamera.update({cam:new[cam]+1})
    else:
        bodycamera.update({cam:1})

# %%
#false checker
manDeath = {}
ageStat = {}
genderStat = {}
raceStat = {}
stateStat= {}
falseSize = len(falseCam)
for i in range(0, len(falseCam)):
    man = falseCam[i][3]
    gender = falseCam[i][6]
    age = falseCam[i][5]
    race = falseCam[i][7]
    state = falseCam[i][9]
    if man in manDeath.keys():
        manDeath.update({man:manDeath[man] + 1})
    else:
        manDeath.update({man:1})
        
    if gender in genderStat.keys():
        genderStat.update({gender:genderStat[gender] + 1})
    else:
        genderStat.update({gender:1})
        
    if age in manDeath.keys():
        ageStat.update({age:ageStat[age] + 1})
    else:
        ageStat.update({age:1})
    
    if race in raceStat.keys():
        raceStat.update({race:raceStat[race] + 1})
    else:
        raceStat.update({race:1})
        
    if state in stateStat.keys():
        stateStat.update({state:stateStat[state] + 1})
    else:
        stateStat.update({state:1})
#print(manDeath)
print("Shot and tasered Percent:", manDeath["shot and Tasered"]/falseSize)
#print(ageStat)
print("Male Gender Percent:", genderStat["M"]/falseSize)
print(genderStat)
print(raceStat)
aP = raceStat["A"]/(falseSize- 271)
wP = raceStat["W"]/(falseSize- 271) 
hP = raceStat["H"]/(falseSize- 271) 
bP = raceStat["B"]/(falseSize- 271) 
oP = raceStat["O"]/(falseSize- 271) 
nP = raceStat["N"]/(falseSize- 271) 
print("Race stats:",aP,":",wP,":",hP,":",bP,":",oP,":",nP)
print(stateStat)
# Out:
# Shot and tasered Percent: 0.05621301775147929
# Male Gender Percent: 0.9539776462853385
# {'M': 2902, 'F': 135, nan: 5}
# {'A': 44, 'W': 1456, 'H': 501, 'B': 695, 'O': 30, nan: 271, 'N': 45}
# Race stats: 0.015878744135691087 : 0.5254420786719596 : 0.18080115481775533 : 0.2508119812342115 : 0.010826416456153013 : 0.01623962468422952
# {'WA': 78, 'OR': 47, 'KS': 31, 'CA': 476, 'CO': 97, 'OK': 90, 'AZ': 145, 'PA': 75, 'TX': 279, 'OH': 95, 'IA': 14, 'MT': 17, 'AR': 39, 'IL': 69, 'NV': 43, 'MN': 33, 'MO': 84, 'VA': 56, 'NJ': 41, 'IN': 54, 'LA': 65, 'KY': 57, 'MA': 25, 'NH': 7, 'FL': 199, 'ID': 22, 'MD': 33, 'NE': 14, 'MI': 51, 'GA': 95, 'TN': 69, 'NC': 78, 'AK': 20, 'NY': 53, 'ME': 15, 'MS': 37, 'UT': 22, 'AL': 60, 'NM': 53, 'WI': 50, 'SC': 46, 'DE': 8, 'DC': 8, 'WV': 34, 'HI': 12, 'WY': 11, 'ND': 7, 'CT': 12, 'SD': 11, 'RI': 2, 'VT': 3}

# %%
manDeath["shot and Tasered"]
# Out:
# 171

# %%
#True checker
manDeath = {}
ageStat = {}
genderStat = {}
raceStat = {}
stateStat= {}
truthSize = len(trueCam)
for i in range(0, len(trueCam)):
    man = trueCam[i][3]
    gender = trueCam[i][6]
    age = trueCam[i][5]
    race = trueCam[i][7]
    state = trueCam[i][9]
    if man in manDeath.keys():
        manDeath.update({man:manDeath[man] + 1})
    else:
        manDeath.update({man:1})
        
    if gender in genderStat.keys():
        genderStat.update({gender:genderStat[gender] + 1})
    else:
        genderStat.update({gender:1})
        
    if age in manDeath.keys():
        ageStat.update({age:ageStat[age] + 1})
    else:
        ageStat.update({age:1})
    
    if race in raceStat.keys():
        raceStat.update({race:raceStat[race] + 1})
    else:
        raceStat.update({race:1})
        
    if state in stateStat.keys():
        stateStat.update({state:stateStat[state] + 1})
    else:
        stateStat.update({state:1})
print("Total:",truthSize)
print(manDeath)
print("Shot and tasered Percent:", manDeath["shot and Tasered"]/truthSize)
#print(ageStat)
#print(genderStat)
print("Male Gender Percent:", genderStat["M"]/truthSize)
print(raceStat)
aP = raceStat["A"]/(truthSize- 18)
wP = raceStat["W"]/(truthSize- 18) 
hP = raceStat["H"]/(truthSize- 18) 
bP = raceStat["B"]/(truthSize- 18) 
oP = raceStat["O"]/(truthSize- 18) 
nP = raceStat["N"]/(truthSize- 18) 
print("Race stats:",aP,":",wP,":",hP,":",bP,":",oP,":",nP)
print(stateStat)
# Out:
# Total: 357
# {'shot': 330, 'shot and Tasered': 27}
# Shot and tasered Percent: 0.07563025210084033
# Male Gender Percent: 0.9663865546218487
# {'W': 150, 'B': 108, 'O': 2, 'H': 61, nan: 18, 'N': 9, 'A': 9}
# Race stats: 0.02654867256637168 : 0.4424778761061947 : 0.17994100294985252 : 0.3185840707964602 : 0.0058997050147492625 : 0.02654867256637168
# {'IA': 4, 'LA': 9, 'UT': 10, 'NM': 14, 'OK': 14, 'AL': 13, 'MI': 5, 'CA': 64, 'GA': 9, 'OH': 7, 'ID': 5, 'VA': 11, 'IN': 8, 'MO': 2, 'CO': 11, 'TX': 23, 'DE': 2, 'NH': 1, 'NC': 14, 'NV': 13, 'IL': 7, 'AZ': 21, 'FL': 9, 'KY': 7, 'VT': 3, 'TN': 8, 'SD': 1, 'OR': 1, 'MN': 5, 'KS': 3, 'SC': 7, 'AR': 1, 'WA': 7, 'WI': 9, 'NE': 1, 'MT': 2, 'DC': 3, 'NJ': 1, 'WV': 3, 'AK': 2, 'MD': 10, 'MS': 2, 'NY': 4, 'RI': 1}

# %%
df
# Out:
#         id                              name        date   manner_of_death  \
# 0        3                        Tim Elliot  2015-01-02              shot
# 1        4                  Lewis Lee Lembke  2015-01-02              shot
# 2        5                John Paul Quintero  2015-01-03  shot and Tasered
# 3        8                   Matthew Hoffman  2015-01-04              shot
# 4        9                 Michael Rodriguez  2015-01-04              shot
# 5       11                 Kenneth Joe Brown  2015-01-04              shot
# 6       13               Kenneth Arnold Buck  2015-01-05              shot
# 7       15                     Brock Nichols  2015-01-06              shot
# 8       16                     Autumn Steele  2015-01-06              shot
# 9       17                   Leslie Sapp III  2015-01-06              shot
# 10      19                    Patrick Wetter  2015-01-06  shot and Tasered
# ...
